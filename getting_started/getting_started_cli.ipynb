# %% [markdown]
# ## This notebook will guide you through the use of the chronix2grid command line interface.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>WARNING</b>: If you run <b>chronix2grid in a virtual env</b>, make sure that you either:
#
#     - sourced your virtual env before launching jupyter: source v_env_chronix2grid/bin/activate
#
#     - created an ipython kernel for this virtual env, and that you are actually running this kernerl now
# </div>

# %%
import os

# %%
# !chronix2grid --help
# Out:
# Usage: chronix2grid [OPTIONS]
#
# Options:
#   --case TEXT               case folder to base generation on
#   --start-date TEXT         Start date to generate chronics
#   --weeks INTEGER           Number of weeks to generate
#   --by-n-weeks INTEGER      Size of the output chunks in weeks
#   --n_scenarios INTEGER     Number of scenarios to generate
#   --mode TEXT               Steps to execute : L(K) for loads only (and
#                             KPI);R(K) for renewables (and KPI) only; LRT (K)
#                             for load, renewable and thermic generation (and
#                             KPI); LRDT(TK) for load, renewable, loss
#                             (dissipation) generation (and thermic and KPI)
#   --input-folder TEXT       Directory to read input files from.
#   --output-folder TEXT      Directory to store output files.
#   --seed-for-loads TEXT     Input seed to ensure reproducibility of loads
#                             generation
#   --seed-for-res TEXT       Input seed to ensure reproducibility of renewables
#                             generation
#   --seed-for-dispatch TEXT  Input seed to ensure reproducibility of dispatch
#   --ignore-warnings         Ignore the warnings related to the existence of
#                             data files in the chosen output directory.
#   --scenario_name TEXT      subname to add to the generated scenario output
#                             folder, as Scenario_subname_i
#   --nb_core INTEGER         number of cores to parallelize the number of
#                             scenarios
#   --help                    Show this message and exit.

# %%
### CONSTANT

notebook_folder=%pwd

# define your input folder
INPUT_FOLDER = os.path.join(notebook_folder, 'example', 'input')

OUTPUT_FOLDER = os.path.join(notebook_folder, 'example', 'output')

# Detailed configuration to be set in <INPUT_FOLDER>/<CASE>/params.json
start_date = "2012-01-01"
weeks = 8
n_scenarios = 1
by_n_weeks = 4

mode = 'RLTK'


CASE = 'case118_l2rpn_wcci'

# %%
cli_chronix2grid="chronix2grid \
                         --mode {} --output-folder {} --input-folder {} --ignore-warnings \
                         --weeks {} --case {} --n_scenarios {} --start-date {} --by-n-weeks {}".format(
                         mode, OUTPUT_FOLDER, INPUT_FOLDER, weeks, CASE, n_scenarios, start_date,by_n_weeks)
cli_chronix2grid
# Out:
# 'chronix2grid                          --mode RLTK --output-folder c:\\c2g_testes\\chronix2grid\\getting_started\\example\\output --input-folder c:\\c2g_testes\\chronix2grid\\getting_started\\example\\input --ignore-warnings                          --weeks 8 --case case118_l2rpn_wcci --n_scenarios 1 --start-date 2012-01-01 --by-n-weeks 4'

# %%
# !$cli_chronix2grid
# Out:
# case118_l2rpn_wcci
# initial_seeds
# {'loads': 1662825239, 'renewables': 1662825239, 'dispatch': 1662825239}
# seeds for scenario: Scenario_0
# {'loads': 1662825239, 'renewables': 1662825239, 'dispatch': 1662825239}
# scenario_path: c:\c2g_testes\chronix2grid\getting_started\example\output\generation\case118_l2rpn_wcci\2012-01-01\Scenario_0
# =====================================================================================================================================
# ============================================== CHRONICS GENERATION ==================================================================
# =====================================================================================================================================
# ================ Generating Scenario_0 ================
# Computing global auto-correlated spatio-temporal noise for thermosensible demand...
# Computing loads ...
# Saving files in zipped csv in "c:\c2g_testes\chronix2grid\getting_started\example\output\generation\case118_l2rpn_wcci\2012-01-01\Scenario_0"
# Computing global auto-correlated spatio-temporal noise for sun and wind...
# Generating solar and wind production chronics
# Saving files in zipped csv
# mode_opf is not None
# Preprocessing input data..
# Filter generators ramps up/down
# Adapting PyPSA grid with parameters..
# mode_opf is not None: month
#
# --> OPF formulation by => month - Analyzing month # 1
# Running HiGHS 1.9.0 (git hash: fa40bdf): Copyright (c) 2024 HiGHS under MIT licence terms
# ERROR:   getOptionIndex: Option "pyomo" is unknown
# Coefficient ranges:
#   Matrix [1e+00, 1e+00]
#   Cost   [1e-01, 5e+01]
#   Bound  [0e+00, 0e+00]
#   RHS    [1e+00, 4e+03]
# Presolving model
# 580256 rows, 285696 cols, 1428352 nonzeros  0s
# 294592 rows, 285696 cols, 857024 nonzeros  1s
# 294592 rows, 285696 cols, 857024 nonzeros  2s
# Presolve : Reductions: rows 294592(-892768); columns 285696(-17856); elements 857024(-1196288)
# Solving the presolved LP
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0     0.0000000000e+00 Pr: 8928(2.92133e+07) 3s
#       70744     1.0488416639e+09 Pr: 13197(146687); Du: 0(2.21151e-07) 8s
#       94572     1.0488622277e+09 Pr: 0(0) 11s
# Solving the original LP from the solution after postsolve
# Model name          : linopy-problem-c0wsc89m
# Model status        : Optimal
# Simplex   iterations: 94572
# Objective value     :  1.0488622277e+09
# Relative P-D gap    :  9.7743999459e-15
# HiGHS run time      :         11.48
# Writing the solution to C:\Users\pedro\AppData\Local\Temp\linopy-solve-flq8lsft.sol
# -- opf succeeded  >Objective value (should be greater than zero!
#
# --> OPF formulation by => month - Analyzing month # 2
# Running HiGHS 1.9.0 (git hash: fa40bdf): Copyright (c) 2024 HiGHS under MIT licence terms
# ERROR:   getOptionIndex: Option "pyomo" is unknown
# Coefficient ranges:
#   Matrix [1e+00, 1e+00]
#   Cost   [1e-01, 5e+01]
#   Bound  [0e+00, 0e+00]
#   RHS    [1e+00, 4e+03]
# Presolving model
# 467871 rows, 230368 cols, 1151712 nonzeros  0s
# 237535 rows, 230368 cols, 691040 nonzeros  1s
# 237535 rows, 230368 cols, 691040 nonzeros  1s
# Presolve : Reductions: rows 237535(-719868); columns 230368(-14398); elements 691040(-964602)
# Solving the presolved LP
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0     0.0000000000e+00 Pr: 7199(2.34686e+07) 2s
#       58450     8.3232753495e+08 Pr: 0(0) 6s
# Solving the original LP from the solution after postsolve
# Model name          : linopy-problem-e_5byp71
# Model status        : Optimal
# Simplex   iterations: 58450
# Objective value     :  8.3232753495e+08
# Relative P-D gap    :  6.2875341636e-14
# HiGHS run time      :          6.73
# Writing the solution to C:\Users\pedro\AppData\Local\Temp\linopy-solve-34jyx6p1.sol
# -- opf succeeded  >Objective value (should be greater than zero!
# Total time 0.99 min
# OPF Done......
# Saving results for the grids with individual generators...
# INFO: wind curtailment max: 0.00MW
# INFO: wind curtailment min: 0.00MW
# INFO: wind curtailment sum: 0.00MWh (total 315306.47MWh: 0.00%)
# INFO: solar curtailment max: 0.00MW
# INFO: solar curtailment min: 0.00MW
# INFO: solar curtailment sum: 0.00MWh (total 0.00MWh: 0.00%)
# applying noise to forecast of 0.01 %
# temporary copy of grid in c:\c2g_testes\chronix2grid\getting_started\example\input\generation\case118_l2rpn_wcci_Scenario_0
# temporary copy of chronics in c:\c2g_testes\chronix2grid\getting_started\example\input\generation\case118_l2rpn_wcci_Scenario_0\chronics\Scenario_0
# Start grid2op simulation to compute realistic loss on grid
# Grid2op simulation for loss
# ---- end of simulation
# Start realistic loss correction from simulation results
# maximum compensation for slack before correction in MW: 55.159393310546875
# average compensation for slack before correction in MW: 28.993161220979854
# median compensation for slack before correction in MW: 28.356908798217773
# min compensation for slack before correction in MW: 10.514900207519531
# Warning - Loss correction violates generator constraints: Ramp up + margin is violated with maximum of 30.07383155822754 MW -
# ---- end of loss correction
#
#
# WARNING: make sure that your generated data is in folder: c:\c2g_testes\chronix2grid\getting_started\example\output\generation\case118_l2rpn_wcci\2012-01-01
# =====================================================================================================================================
# ================================================= KPI GENERATION  ===================================================================
# =====================================================================================================================================
# Scenario_0...
# Warning: KPI are incomplete. Computation has been made on 8 weeks, but are meant to be computed on 52 weeks
# Importing and formatting data downloaded from regional eco2mix data
# Importing and formatting synthetic chronics
# (1) Computing KPI's...
# Warning: prices data have not been given for both synthetic and reference dispatch. Quantiles will be computed on demand instead. Next time, you can provide .../France/eco2mix/prices_2012.csv.bz2
#
#
#
# Shape da wind sintetica: (1344,)
#
#
#
#
# Shape da wind referencia: (1344,)
#
#
# (2) Generating json output file...
# -Done-
# C:\Users\pedro\anaconda3\envs\env_cg2_q\lib\site-packages\chronix2grid\generation\dispatch\EconomicDispatch.py:197: FutureWarning:
#
# The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#
# WARNING:pypsa.consistency:The following buses have carriers which are not defined:
# Index(['node'], dtype='object', name='Bus')
# WARNING:pypsa.consistency:The following generators have carriers which are not defined:
# Index(['gen_7_2', 'gen_9_3', 'gen_11_6', 'gen_14_8', 'gen_17_10', 'gen_18_11',
#        'gen_25_13', 'gen_33_16', 'gen_41_18', 'gen_41_19', 'gen_45_20',
#        'gen_54_26', 'gen_55_29', 'gen_60_32', 'gen_64_35', 'gen_65_36',
#        'gen_68_37', 'gen_69_38', 'gen_69_39', 'gen_75_40', 'gen_76_41',
#        'gen_76_42', 'gen_82_45', 'gen_84_46', 'gen_86_47', 'gen_91_51',
#        'gen_99_53', 'gen_103_55', 'gen_104_56', 'gen_110_58', 'gen_112_60',
#        'gen_115_61', 'agg_solar', 'agg_wind'],
#       dtype='object', name='Generator')
# WARNING:pypsa.consistency:The following buses have carriers which are not defined:
# Index(['node'], dtype='object', name='Bus')
# WARNING:pypsa.consistency:The following generators have carriers which are not defined:
# Index(['gen_7_2', 'gen_9_3', 'gen_11_6', 'gen_14_8', 'gen_17_10', 'gen_18_11',
#        'gen_25_13', 'gen_33_16', 'gen_41_18', 'gen_41_19', 'gen_45_20',
#        'gen_54_26', 'gen_55_29', 'gen_60_32', 'gen_64_35', 'gen_65_36',
#        'gen_68_37', 'gen_69_38', 'gen_69_39', 'gen_75_40', 'gen_76_41',
#        'gen_76_42', 'gen_82_45', 'gen_84_46', 'gen_86_47', 'gen_91_51',
#        'gen_99_53', 'gen_103_55', 'gen_104_56', 'gen_110_58', 'gen_112_60',
#        'gen_115_61', 'agg_solar', 'agg_wind'],
#       dtype='object', name='Generator')
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.model:Solver options:
#  - pyomo: False
# INFO:linopy.io:Writing objective.
#
# Writing constraints.:   0%|          | 0/5 [00:00<?, ?it/s]
# Writing constraints.:  20%|██        | 1/5 [00:00<00:03,  1.01it/s]
# Writing constraints.:  40%|████      | 2/5 [00:02<00:03,  1.01s/it]
# Writing constraints.:  60%|██████    | 3/5 [00:03<00:02,  1.30s/it]
# Writing constraints.:  80%|████████  | 4/5 [00:05<00:01,  1.42s/it]
# Writing constraints.: 100%|██████████| 5/5 [00:05<00:00,  1.15s/it]
# Writing constraints.: 100%|██████████| 5/5 [00:05<00:00,  1.19s/it]
#
# Writing continuous variables.:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing continuous variables.: 100%|██████████| 1/1 [00:00<00:00,  1.68it/s]
# Writing continuous variables.: 100%|██████████| 1/1 [00:00<00:00,  1.68it/s]
# INFO:linopy.io: Writing time: 7.0s
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 303552 primals, 1187360 duals
# Objective: 1.05e+09
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-fix-p-lower, Generator-fix-p-upper, Generator-fix-p-ramp_limit_up, Generator-fix-p-ramp_limit_down were not assigned to the network.
# WARNING:pypsa.consistency:The following buses have carriers which are not defined:
# Index(['node'], dtype='object', name='Bus')
# WARNING:pypsa.consistency:The following generators have carriers which are not defined:
# Index(['gen_7_2', 'gen_9_3', 'gen_11_6', 'gen_14_8', 'gen_17_10', 'gen_18_11',
#        'gen_25_13', 'gen_33_16', 'gen_41_18', 'gen_41_19', 'gen_45_20',
#        'gen_54_26', 'gen_55_29', 'gen_60_32', 'gen_64_35', 'gen_65_36',
#        'gen_68_37', 'gen_69_38', 'gen_69_39', 'gen_75_40', 'gen_76_41',
#        'gen_76_42', 'gen_82_45', 'gen_84_46', 'gen_86_47', 'gen_91_51',
#        'gen_99_53', 'gen_103_55', 'gen_104_56', 'gen_110_58', 'gen_112_60',
#        'gen_115_61', 'agg_solar', 'agg_wind'],
#       dtype='object', name='Generator')
# WARNING:pypsa.consistency:The following buses have carriers which are not defined:
# Index(['node'], dtype='object', name='Bus')
# WARNING:pypsa.consistency:The following generators have carriers which are not defined:
# Index(['gen_7_2', 'gen_9_3', 'gen_11_6', 'gen_14_8', 'gen_17_10', 'gen_18_11',
#        'gen_25_13', 'gen_33_16', 'gen_41_18', 'gen_41_19', 'gen_45_20',
#        'gen_54_26', 'gen_55_29', 'gen_60_32', 'gen_64_35', 'gen_65_36',
#        'gen_68_37', 'gen_69_38', 'gen_69_39', 'gen_75_40', 'gen_76_41',
#        'gen_76_42', 'gen_82_45', 'gen_84_46', 'gen_86_47', 'gen_91_51',
#        'gen_99_53', 'gen_103_55', 'gen_104_56', 'gen_110_58', 'gen_112_60',
#        'gen_115_61', 'agg_solar', 'agg_wind'],
#       dtype='object', name='Generator')
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.model:Solver options:
#  - pyomo: False
# INFO:linopy.io:Writing objective.
#
# Writing constraints.:   0%|          | 0/5 [00:00<?, ?it/s]
# Writing constraints.:  20%|██        | 1/5 [00:00<00:03,  1.13it/s]
# Writing constraints.:  40%|████      | 2/5 [00:01<00:02,  1.16it/s]
# Writing constraints.:  60%|██████    | 3/5 [00:03<00:02,  1.11s/it]
# Writing constraints.:  80%|████████  | 4/5 [00:04<00:01,  1.21s/it]
# Writing constraints.: 100%|██████████| 5/5 [00:05<00:00,  1.03it/s]
# Writing constraints.: 100%|██████████| 5/5 [00:05<00:00,  1.01s/it]
#
# Writing continuous variables.:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing continuous variables.: 100%|██████████| 1/1 [00:00<00:00,  2.03it/s]
# Writing continuous variables.: 100%|██████████| 1/1 [00:00<00:00,  2.03it/s]
# INFO:linopy.io: Writing time: 6.0s
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 244766 primals, 957403 duals
# Objective: 8.32e+08
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-fix-p-lower, Generator-fix-p-upper, Generator-fix-p-ramp_limit_up, Generator-fix-p-ramp_limit_down were not assigned to the network.
# INFO:pandapower.convert_format:These dtypes could not be corrected: {'trafo': ['tap_neutral', 'tap_min', 'tap_max', 'tap_pos']}
# C:\Users\pedro\anaconda3\envs\env_cg2_q\lib\site-packages\lightsim2grid\gridmodel\from_pandapower\_aux_add_trafo.py:38: UserWarning:
#
# There were some Nan in the pp_net.trafo["tap_neutral"], they have been replaced by 0
#
# C:\Users\pedro\anaconda3\envs\env_cg2_q\lib\site-packages\lightsim2grid\gridmodel\from_pandapower\_aux_add_trafo.py:46: UserWarning:
#
# There were some Nan in the pp_net.trafo["tap_step_percent"], they have been replaced by 0
#
# C:\Users\pedro\anaconda3\envs\env_cg2_q\lib\site-packages\lightsim2grid\gridmodel\from_pandapower\_aux_add_trafo.py:51: UserWarning:
#
# There were some Nan in the pp_net.trafo["tap_pos"], they have been replaced by 0
#
# C:\Users\pedro\anaconda3\envs\env_cg2_q\lib\site-packages\lightsim2grid\gridmodel\from_pandapower\_aux_add_trafo.py:79: UserWarning:
#
# There were some Nan in the pp_net.trafo["tap_step_degree"], they have been replaced by 0
#
# C:\Users\pedro\anaconda3\envs\env_cg2_q\lib\site-packages\lightsim2grid\gridmodel\from_pandapower\_aux_add_slack.py:114: UserWarning:
#
# We found either some slack coefficient to be < 0. or they were all 0.We set them all to 1.0 to avoid such issues
#
# INFO:pandapower.convert_format:These dtypes could not be corrected: {'trafo': ['tap_neutral', 'tap_min', 'tap_max', 'tap_pos']}
#
# episode:   0%|          | 0/16126 [00:00<?, ?it/s]
# episode:   0%|          | 57/16126 [00:00<00:28, 567.78it/s]
# episode:   1%|          | 116/16126 [00:00<00:27, 580.78it/s]
# episode:   1%|          | 175/16126 [00:00<00:28, 565.65it/s]
# episode:   1%|▏         | 235/16126 [00:00<00:27, 576.46it/s]
# episode:   2%|▏         | 295/16126 [00:00<00:27, 582.22it/s]
# episode:   2%|▏         | 354/16126 [00:00<00:26, 584.15it/s]
# episode:   3%|▎         | 413/16126 [00:00<00:27, 577.99it/s]
# episode:   3%|▎         | 471/16126 [00:00<00:27, 574.75it/s]
# episode:   3%|▎         | 529/16126 [00:00<00:27, 568.92it/s]
# episode:   4%|▎         | 586/16126 [00:01<00:27, 555.26it/s]
# episode:   4%|▍         | 644/16126 [00:01<00:27, 561.45it/s]
# episode:  89%|████████▉ | 14337/16126 [00:26<00:03, 566.71it/s]
# episode:  89%|████████▉ | 14397/16126 [00:26<00:03, 573.17it/s]
# episode:  90%|████████▉ | 14455/16126 [00:26<00:02, 573.47it/s]
# episode:  90%|████████▉ | 14513/16126 [00:26<00:02, 574.31it/s]
# episode:  90%|█████████ | 14571/16126 [00:26<00:02, 570.29it/s]
# episode:  91%|█████████ | 14629/16126 [00:26<00:02, 568.10it/s]
# episode:  91%|█████████ | 14688/16126 [00:26<00:02, 574.26it/s]
# episode:  91%|█████████▏| 14746/16126 [00:26<00:02, 568.18it/s]
# episode:  92%|█████████▏| 14803/16126 [00:26<00:02, 563.64it/s]
# episode:  92%|█████████▏| 14860/16126 [00:27<00:02, 558.04it/s]
# episode:  92%|█████████▏| 14916/16126 [00:27<00:02, 557.21it/s]
# episode:  93%|█████████▎| 14972/16126 [00:27<00:02, 557.92it/s]
# episode:  93%|█████████▎| 15028/16126 [00:27<00:02, 548.82it/s]
# episode:  94%|█████████▎| 15086/16126 [00:27<00:01, 557.39it/s]
# episode:  94%|█████████▍| 15142/16126 [00:27<00:01, 556.04it/s]
# episode:  94%|█████████▍| 15199/16126 [00:27<00:01, 559.05it/s]
# episode:  95%|█████████▍| 15257/16126 [00:27<00:01, 561.97it/s]
# episode:  95%|█████████▍| 15314/16126 [00:27<00:01, 556.01it/s]
# episode:  95%|█████████▌| 15370/16126 [00:27<00:01, 548.52it/s]
# episode:  96%|█████████▌| 15425/16126 [00:28<00:01, 533.40it/s]
# episode:  96%|█████████▌| 15483/16126 [00:28<00:01, 545.00it/s]
# episode:  96%|█████████▋| 15540/16126 [00:28<00:01, 550.64it/s]
# episode:  97%|█████████▋| 15598/16126 [00:28<00:00, 558.45it/s]
# episode:  97%|█████████▋| 15654/16126 [00:28<00:01, 355.32it/s]
# episode:  97%|█████████▋| 15711/16126 [00:28<00:01, 400.35it/s]
# episode:  98%|█████████▊| 15767/16126 [00:28<00:00, 435.80it/s]
# episode:  98%|█████████▊| 15825/16126 [00:28<00:00, 469.87it/s]
# episode:  98%|█████████▊| 15883/16126 [00:29<00:00, 497.69it/s]
# episode:  99%|█████████▉| 15942/16126 [00:29<00:00, 522.45it/s]
# episode:  99%|█████████▉| 15998/16126 [00:29<00:00, 519.89it/s]
# episode: 100%|█████████▉| 16054/16126 [00:29<00:00, 528.21it/s]
# episode: 100%|█████████▉| 16112/16126 [00:29<00:00, 541.85it/s]
# episode: 100%|██████████| 16126/16126 [00:29<00:00, 546.91it/s]
# INFO:grid2op.Environment.baseEnv.grid2op_Runner:Env: 21.88s
# 	 - apply act 10.05s
# 	 - run pf: 5.35s
# 	 - env update + observation: 6.48s
# Agent: 0.80s
# Total time: 29.49s
# Cumulative reward: 726160.875000
# C:\Users\pedro\anaconda3\envs\env_cg2_q\lib\site-packages\chronix2grid\generation\dispatch\dispatch_loss_utils.py:203: UserWarning:
#
# Loss correction violates generator constraints: Ramp up + margin is violated with maximum of 30.07383155822754 MW -
